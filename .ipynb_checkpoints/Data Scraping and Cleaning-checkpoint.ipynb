# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import requests
import pandas as pd
import numpy as np
import re
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Scrape data from Spotify

# %%
access_token = 'BQAhG-KB_TU5tZWRo6p5JDQr6a0udHfgxsaMbQ1y_4lc17ctwqy8OlI5eRPhoR_ynbomfTnF-u9oEcE-G5NjLEWa8hB92EvXD2uoiZQ9WdAkyKaXGfOQMF_Y8-gSvTfPyP8ADZQNWy5JWN7ycS0fPiNDRkc34gk'

# %%
Artist_IDs = ['4q3ewBCX7sLwd24euuV69X', '3TVXtAsR1Inumwj472S9r4', '1vyhD5VmyZ7KMfW5gqLgo5','4MCBfE4596Uoi2O4DtmEMz', '1Xyo4u8uXC1ZmMpatF05PJ',
'3Nrfpe0tUJi4K4DXYWgMUX','6qqNVTkY8uBg9cP3Jd7DAH','06HL4z0CvFAxyc27GXpf02','246dkjvS1zLTtiykXe5h60','0Y5tJX1MQlPlqiwlOH1tJY',
'66CXWjxzNUsdJxJ2JdwvnR','1uNFoZAHBGtllmzznpCI3s','7dGJo4pcD2V6oG8kP0tJRR','2R21vXR83lH98kGeO99Y66','6M2wZ9GZgrQXHCFfjv46we',
'1i8SpTcr7yvPOmcqrbnVXY','6eUKZXaKkcviH0Ku9w2n3V','15UsOTVnJzReFVN1VCnxy4','6LuN9FCkKOj5PcnpouEgny','4VMYDCV2IEDYJArk749S6m',
'4SsVbpTthjScTS7U2hmr1X','0eDvMgVFoNV3TpwtrVCoTj','4r63FhuTkUYltbVAg5TQnk','6KImCVD70vtIoJWnq6nGn3','4O15NlyKLIASxsJ0PrXPfz',
'26VFTg2z8YR0cCuwLzESi2','1HY2Jd0NmPuamShAr6KMms','7iK8PXO48WeuP03g8YR51W','1mcTU81TzQhprhouKaTkpq','757aE44tKEUQEqRuT6GnEB',
'5K4W6rqBFWDnAN6FQUkS6x','1r4hJ1h58CWwUQe3MxPuau','04gDigrS5kc9YWfZHwBETP','1dfeR4HaWDbWqFHLkxsg1d','0hCNtLu0JehylgoiP8L4Gh',
'4AK6F7OLvEQ5QYCBNiQWHq','1RyvyyTE3xzB2ZywiAwp0i','329e4yvIujISKGKz1BZZbO','53XhwfbYqKCa1cC15pYq2q','64KEffDW9EtZ1y2vBYgq8T',
'7n2wHs1TKAczGzO7Dd2rGr','5pKCCKE2ajJHZ9KAiaK11H','3WrFJ7ztbogyGnTHbHJFl2','4gzpq5DPGxSnKTe4SA8HAU','2wY79sveU1sp5g7SokKOiI',
'4GNC7GD6oZMSxPGyXy4MNB','4nDoRrQiYLoBzwC5BhVJzF','0C8ZW7ezQVs4URX5aX7Kqx', '5cj0lLjcoR7YOSnhnX0Po5','23fqKkggKUBHNkbKtXEls4']

# %%
df1 = pd.DataFrame()
for ID in Artist_IDs:
    url = f'https://api.spotify.com/v1/artists/{ID}'
    headers = {
        'Authorization': 'Bearer {token}'.format(token=access_token)
    }
    req = requests.get(url, headers=headers)
    data = req.json()
    
    lines = []
    for genre in data['genres']:
        line = {'id': data['id'], 
                'name': data['name'],
                'genre': genre,
                'followers': data['followers']['total'], 
                'popularity': data['popularity'] }
        lines.append(line)
    df1 = df1.append(lines, ignore_index=True)

# %%
df1
# Out:
#                          id       name             genre  followers  \
# 0    4q3ewBCX7sLwd24euuV69X  Bad Bunny             latin   32476412
# 1    4q3ewBCX7sLwd24euuV69X  Bad Bunny         reggaeton   32476412
# 2    4q3ewBCX7sLwd24euuV69X  Bad Bunny       trap latino   32476412
# 3    3TVXtAsR1Inumwj472S9r4      Drake  canadian hip hop   54510167
# 4    3TVXtAsR1Inumwj472S9r4      Drake      canadian pop   54510167
# ..                      ...        ...               ...        ...
# 158  5cj0lLjcoR7YOSnhnX0Po5   Doja Cat           pop rap    6297686
# 159  23fqKkggKUBHNkbKtXEls4       Kygo               edm    7380824
# 160  23fqKkggKUBHNkbKtXEls4       Kygo               pop    7380824
# 161  23fqKkggKUBHNkbKtXEls4       Kygo         pop dance    7380824
# 162  23fqKkggKUBHNkbKtXEls4       Kygo    tropical house    7380824
#
#      popularity
# 0            98
# 1            98
# 2            98
# 3            98
# 4            98
# ..          ...
# 158          92
# 159          86
# 160          86
# 161          86
# 162          86
#
# [163 rows x 5 columns]

# %%
df1.to_csv('data/raw_artists.csv', index = False)

# %%
df2 = pd.DataFrame()
for ID in Artist_IDs:
    url = f'https://api.spotify.com/v1/artists/{ID}/top-tracks?market=US'
    headers = {
        'Authorization': 'Bearer {token}'.format(token=access_token)
    }
    req = requests.get(url, headers=headers)
    data = req.json()

    lines = []
    for track in data['tracks']:
        for artist in track['artists']:
            line = {'album_name': track['album']['name'], 
                    'album_release_date': track['album']['release_date'],
                    'artists_name': artist['name'], 
                    'artists_id': artist['id'] }
            for k in ['duration_ms', 'explicit', 'name', 'popularity']:
                line[k] = track[k]
            line['external_urls'] = track['external_urls']['spotify']
            lines.append(line)
    df2 = df2.append(lines, ignore_index=True)

# %%
df2
# Out:
#                    album_name album_release_date    artists_name  \
# 0    EL ÚLTIMO TOUR DEL MUNDO         2020-11-27       Bad Bunny
# 1    EL ÚLTIMO TOUR DEL MUNDO         2020-11-27         ROSALÍA
# 2    EL ÚLTIMO TOUR DEL MUNDO         2020-11-27       Bad Bunny
# 3    EL ÚLTIMO TOUR DEL MUNDO         2020-11-27     Jhay Cortez
# 4    EL ÚLTIMO TOUR DEL MUNDO         2020-11-27       Bad Bunny
# ..                        ...                ...             ...
# 908                 Happy Now         2018-10-26  Sandro Cavazza
# 909                 Hot Stuff         2020-09-18            Kygo
# 910                 Hot Stuff         2020-09-18    Donna Summer
# 911               Golden Hour         2020-05-29            Kygo
# 912               Golden Hour         2020-05-29     Sasha Sloan
#
#                  artists_id  duration_ms  explicit                name  \
# 0    4q3ewBCX7sLwd24euuV69X       203200     False  LA NOCHE DE ANOCHE
# 1    7ltDVBr6mKbRvohxheJ9h1       203200     False  LA NOCHE DE ANOCHE
# 2    4q3ewBCX7sLwd24euuV69X       205090      True              DÁKITI
# 3    0EFisYRi20PTADoJrifHrz       205090      True              DÁKITI
# 4    4q3ewBCX7sLwd24euuV69X       130013      True          TE MUDASTE
# ..                      ...          ...       ...                 ...
# 908  5JYo7gm2dkyLLlWHjxS7Dy       211362     False           Happy Now
# 909  23fqKkggKUBHNkbKtXEls4       199007     False           Hot Stuff
# 910  2eogQKWWoohI3BSnoG7E2U       199007     False           Hot Stuff
# 911  23fqKkggKUBHNkbKtXEls4       215360     False           I'll Wait
# 912  4xnihxcoXWK3UqryOSnbw5       215360     False           I'll Wait
#
#      popularity                                      external_urls
# 0            92  https://open.spotify.com/track/2XIc1pqjXV3Cr2B...
# 1            92  https://open.spotify.com/track/2XIc1pqjXV3Cr2B...
# 2            89  https://open.spotify.com/track/4MzXwWMhyBbmu6h...
# 3            89  https://open.spotify.com/track/4MzXwWMhyBbmu6h...
# 4            87  https://open.spotify.com/track/5RubKOuDoPn5Kj5...
# ..          ...                                                ...
# 908          74  https://open.spotify.com/track/14sOS5L36385FJ3...
# 909          74  https://open.spotify.com/track/00ETaeHUQ6lops3...
# 910          74  https://open.spotify.com/track/00ETaeHUQ6lops3...
# 911          64  https://open.spotify.com/track/1tuXOJYN6Ckgubp...
# 912          64  https://open.spotify.com/track/1tuXOJYN6Ckgubp...
#
# [913 rows x 9 columns]

# %%
df2.to_csv('data/raw_tracks.csv', index = False)

# %% [markdown]
# # 2. Clean raw data
#
# ## 2.1 Artists file

# %%
df1 = pd.read_csv('data/raw_artists.csv')

# %%
df1
# Out:
#                          id       name             genre  followers  \
# 0    4q3ewBCX7sLwd24euuV69X  Bad Bunny             latin   32476412
# 1    4q3ewBCX7sLwd24euuV69X  Bad Bunny         reggaeton   32476412
# 2    4q3ewBCX7sLwd24euuV69X  Bad Bunny       trap latino   32476412
# 3    3TVXtAsR1Inumwj472S9r4      Drake  canadian hip hop   54510167
# 4    3TVXtAsR1Inumwj472S9r4      Drake      canadian pop   54510167
# ..                      ...        ...               ...        ...
# 158  5cj0lLjcoR7YOSnhnX0Po5   Doja Cat           pop rap    6297686
# 159  23fqKkggKUBHNkbKtXEls4       Kygo               edm    7380824
# 160  23fqKkggKUBHNkbKtXEls4       Kygo               pop    7380824
# 161  23fqKkggKUBHNkbKtXEls4       Kygo         pop dance    7380824
# 162  23fqKkggKUBHNkbKtXEls4       Kygo    tropical house    7380824
#
#      popularity
# 0            98
# 1            98
# 2            98
# 3            98
# 4            98
# ..          ...
# 158          92
# 159          86
# 160          86
# 161          86
# 162          86
#
# [163 rows x 5 columns]

# %%
df1['new_genre'] = np.where(df1.genre.str.contains('hip hop|r&b|urban contemporary'), 'Hiphop', '')
df1['new_genre'] = np.where(df1.genre.str.contains('pop|british invasion|merseybeat|boy band|talent show|beatlesque'),  'Pop', df1['new_genre'] )
df1['new_genre'] = np.where(df1.genre.str.contains('rock|permanent wave'),'Rock', df1['new_genre'] )
df1['new_genre'] = np.where(df1.genre.str.contains('latin|latino|reggaeton|tropical'), 'Latino', df1['new_genre'] )
df1['new_genre'] = np.where(df1.genre.str.contains('rap'), 'Rap', df1['new_genre'] )
df1['new_genre'] = np.where(df1.genre.str.contains('drill|trap'), 'Trap', df1['new_genre'] )
df1['new_genre'] = np.where(df1.genre.str.contains('house|edm|brostep'), 'House', df1['new_genre'])

df1
# Out:
#                          id       name             genre  followers  \
# 0    4q3ewBCX7sLwd24euuV69X  Bad Bunny             latin   32476412
# 1    4q3ewBCX7sLwd24euuV69X  Bad Bunny         reggaeton   32476412
# 2    4q3ewBCX7sLwd24euuV69X  Bad Bunny       trap latino   32476412
# 3    3TVXtAsR1Inumwj472S9r4      Drake  canadian hip hop   54510167
# 4    3TVXtAsR1Inumwj472S9r4      Drake      canadian pop   54510167
# ..                      ...        ...               ...        ...
# 158  5cj0lLjcoR7YOSnhnX0Po5   Doja Cat           pop rap    6297686
# 159  23fqKkggKUBHNkbKtXEls4       Kygo               edm    7380824
# 160  23fqKkggKUBHNkbKtXEls4       Kygo               pop    7380824
# 161  23fqKkggKUBHNkbKtXEls4       Kygo         pop dance    7380824
# 162  23fqKkggKUBHNkbKtXEls4       Kygo    tropical house    7380824
#
#      popularity new_genre
# 0            98    Latino
# 1            98    Latino
# 2            98      Trap
# 3            98    Hiphop
# 4            98       Pop
# ..          ...       ...
# 158          92       Rap
# 159          86     House
# 160          86       Pop
# 161          86       Pop
# 162          86     House
#
# [163 rows x 6 columns]

# %%
df1 = df1[['id','name'	,'followers','popularity','new_genre']].drop_duplicates()
df1
# Out:
#                          id          name  followers  popularity new_genre
# 0    4q3ewBCX7sLwd24euuV69X     Bad Bunny   32476412          98    Latino
# 2    4q3ewBCX7sLwd24euuV69X     Bad Bunny   32476412          98      Trap
# 3    3TVXtAsR1Inumwj472S9r4         Drake   54510167          98    Hiphop
# 4    3TVXtAsR1Inumwj472S9r4         Drake   54510167          98       Pop
# 6    3TVXtAsR1Inumwj472S9r4         Drake   54510167          98       Rap
# ..                      ...           ...        ...         ...       ...
# 153  0C8ZW7ezQVs4URX5aX7Kqx  Selena Gomez   26808434          89       Pop
# 156  5cj0lLjcoR7YOSnhnX0Po5      Doja Cat    6297686          92       Pop
# 158  5cj0lLjcoR7YOSnhnX0Po5      Doja Cat    6297686          92       Rap
# 159  23fqKkggKUBHNkbKtXEls4          Kygo    7380824          86     House
# 160  23fqKkggKUBHNkbKtXEls4          Kygo    7380824          86       Pop
#
# [80 rows x 5 columns]

# %%
df1.to_csv('data/cleaned_artists.csv', index=False)

# %% [markdown]
# ## 2.2 Clean track data

# %%
df1.name.unique()
# Out:
# array(['Bad Bunny', 'Drake', 'J Balvin', 'Juice WRLD', 'The Weeknd',
#        'BTS', 'Billie Eilish', 'Taylor Swift', 'Post Malone',
#        'Travis Scott', 'Ariana Grande', 'Justin Bieber', 'Eminem',
#        'Anuel AA', 'Dua Lipa', 'Ozuna', 'Ed Sheeran', 'XXXTENTACION',
#        'Khalid', 'Daddy Yankee', 'Arcangel', 'Pop Smoke', 'DaBaby',
#        'Harry Styles', 'Lil Uzi Vert', 'Halsey', 'Lady Gaga',
#        'Myke Towers', 'Rauw Alejandro', 'Roddy Ricch', 'Kanye West',
#        'Maluma', 'Maroon 5', 'Queen', 'Nicki Minaj', 'One Direction',
#        'Future', 'Farruko', 'Imagine Dragons', 'Marshmello',
#        'Shawn Mendes', 'Rihanna', 'The Beatles', 'Coldplay', 'Sam Smith',
#        'Lewis Capaldi', 'Camila Cabello', 'Selena Gomez', 'Doja Cat',
#        'Kygo'], dtype=object)

# %%
df2 = pd.read_csv('data/raw_tracks.csv')
df2
# Out:
#                    album_name album_release_date    artists_name  \
# 0    EL ÚLTIMO TOUR DEL MUNDO         2020-11-27       Bad Bunny
# 1    EL ÚLTIMO TOUR DEL MUNDO         2020-11-27         ROSALÍA
# 2    EL ÚLTIMO TOUR DEL MUNDO         2020-11-27       Bad Bunny
# 3    EL ÚLTIMO TOUR DEL MUNDO         2020-11-27     Jhay Cortez
# 4    EL ÚLTIMO TOUR DEL MUNDO         2020-11-27       Bad Bunny
# ..                        ...                ...             ...
# 908                 Happy Now         2018-10-26  Sandro Cavazza
# 909                 Hot Stuff         2020-09-18            Kygo
# 910                 Hot Stuff         2020-09-18    Donna Summer
# 911               Golden Hour         2020-05-29            Kygo
# 912               Golden Hour         2020-05-29     Sasha Sloan
#
#                  artists_id  duration_ms  explicit                name  \
# 0    4q3ewBCX7sLwd24euuV69X       203200     False  LA NOCHE DE ANOCHE
# 1    7ltDVBr6mKbRvohxheJ9h1       203200     False  LA NOCHE DE ANOCHE
# 2    4q3ewBCX7sLwd24euuV69X       205090      True              DÁKITI
# 3    0EFisYRi20PTADoJrifHrz       205090      True              DÁKITI
# 4    4q3ewBCX7sLwd24euuV69X       130013      True          TE MUDASTE
# ..                      ...          ...       ...                 ...
# 908  5JYo7gm2dkyLLlWHjxS7Dy       211362     False           Happy Now
# 909  23fqKkggKUBHNkbKtXEls4       199007     False           Hot Stuff
# 910  2eogQKWWoohI3BSnoG7E2U       199007     False           Hot Stuff
# 911  23fqKkggKUBHNkbKtXEls4       215360     False           I'll Wait
# 912  4xnihxcoXWK3UqryOSnbw5       215360     False           I'll Wait
#
#      popularity                                      external_urls
# 0            92  https://open.spotify.com/track/2XIc1pqjXV3Cr2B...
# 1            92  https://open.spotify.com/track/2XIc1pqjXV3Cr2B...
# 2            89  https://open.spotify.com/track/4MzXwWMhyBbmu6h...
# 3            89  https://open.spotify.com/track/4MzXwWMhyBbmu6h...
# 4            87  https://open.spotify.com/track/5RubKOuDoPn5Kj5...
# ..          ...                                                ...
# 908          74  https://open.spotify.com/track/14sOS5L36385FJ3...
# 909          74  https://open.spotify.com/track/00ETaeHUQ6lops3...
# 910          74  https://open.spotify.com/track/00ETaeHUQ6lops3...
# 911          64  https://open.spotify.com/track/1tuXOJYN6Ckgubp...
# 912          64  https://open.spotify.com/track/1tuXOJYN6Ckgubp...
#
# [913 rows x 9 columns]

# %%
artist_list = df1.name.unique()
artist_list
# Out:
# array(['Bad Bunny', 'Drake', 'J Balvin', 'Juice WRLD', 'The Weeknd',
#        'BTS', 'Billie Eilish', 'Taylor Swift', 'Post Malone',
#        'Travis Scott', 'Ariana Grande', 'Justin Bieber', 'Eminem',
#        'Anuel AA', 'Dua Lipa', 'Ozuna', 'Ed Sheeran', 'XXXTENTACION',
#        'Khalid', 'Daddy Yankee', 'Arcangel', 'Pop Smoke', 'DaBaby',
#        'Harry Styles', 'Lil Uzi Vert', 'Halsey', 'Lady Gaga',
#        'Myke Towers', 'Rauw Alejandro', 'Roddy Ricch', 'Kanye West',
#        'Maluma', 'Maroon 5', 'Queen', 'Nicki Minaj', 'One Direction',
#        'Future', 'Farruko', 'Imagine Dragons', 'Marshmello',
#        'Shawn Mendes', 'Rihanna', 'The Beatles', 'Coldplay', 'Sam Smith',
#        'Lewis Capaldi', 'Camila Cabello', 'Selena Gomez', 'Doja Cat',
#        'Kygo'], dtype=object)

# %%
df2.artists_name.nunique()
# Out:
# 213

# %%
df2['test'] = np.where(df2.artists_name.isin(artist_list) , 'yes', 'no')

# %%
df2 = df2[df2['test'] == 'yes']
df2
# Out:
#                          album_name album_release_date artists_name  \
# 0          EL ÚLTIMO TOUR DEL MUNDO         2020-11-27    Bad Bunny
# 2          EL ÚLTIMO TOUR DEL MUNDO         2020-11-27    Bad Bunny
# 4          EL ÚLTIMO TOUR DEL MUNDO         2020-11-27    Bad Bunny
# 5    UN DIA (ONE DAY) (Feat. Tainy)         2020-07-24     J Balvin
# 7    UN DIA (ONE DAY) (Feat. Tainy)         2020-07-24     Dua Lipa
# ..                              ...                ...          ...
# 903                     Golden Hour         2020-05-29         Kygo
# 905                      Cloud Nine         2016-05-13         Kygo
# 907                       Happy Now         2018-10-26         Kygo
# 909                       Hot Stuff         2020-09-18         Kygo
# 911                     Golden Hour         2020-05-29         Kygo
#
#                  artists_id  duration_ms  explicit  \
# 0    4q3ewBCX7sLwd24euuV69X       203200     False
# 2    4q3ewBCX7sLwd24euuV69X       205090      True
# 4    4q3ewBCX7sLwd24euuV69X       130013      True
# 5    1vyhD5VmyZ7KMfW5gqLgo5       232253     False
# 7    6M2wZ9GZgrQXHCFfjv46we       232253     False
# ..                      ...          ...       ...
# 903  23fqKkggKUBHNkbKtXEls4       198635     False
# 905  23fqKkggKUBHNkbKtXEls4       223186     False
# 907  23fqKkggKUBHNkbKtXEls4       211362     False
# 909  23fqKkggKUBHNkbKtXEls4       199007     False
# 911  23fqKkggKUBHNkbKtXEls4       215360     False
#
#                                name  popularity  \
# 0                LA NOCHE DE ANOCHE          92
# 2                            DÁKITI          89
# 4                        TE MUDASTE          87
# 5    UN DIA (ONE DAY) (Feat. Tainy)          86
# 7    UN DIA (ONE DAY) (Feat. Tainy)          86
# ..                              ...         ...
# 903                         Freedom          66
# 905                  Stole the Show          74
# 907                       Happy Now          74
# 909                       Hot Stuff          74
# 911                       I'll Wait          64
#
#                                          external_urls test
# 0    https://open.spotify.com/track/2XIc1pqjXV3Cr2B...  yes
# 2    https://open.spotify.com/track/4MzXwWMhyBbmu6h...  yes
# 4    https://open.spotify.com/track/5RubKOuDoPn5Kj5...  yes
# 5    https://open.spotify.com/track/0EhpEsp4L0oRGM0...  yes
# 7    https://open.spotify.com/track/0EhpEsp4L0oRGM0...  yes
# ..                                                 ...  ...
# 903  https://open.spotify.com/track/2nx0EIlIKMnMgWn...  yes
# 905  https://open.spotify.com/track/5masKPHeAOVNgxd...  yes
# 907  https://open.spotify.com/track/14sOS5L36385FJ3...  yes
# 909  https://open.spotify.com/track/00ETaeHUQ6lops3...  yes
# 911  https://open.spotify.com/track/1tuXOJYN6Ckgubp...  yes
#
# [634 rows x 10 columns]

# %%
df2.to_csv('data/cleaned_tracks.csv', index=False)

# %%
genres = " ".join(str(genre) for genre in df1.new_genre)
genres
# Out:
# 'Latino Trap Hiphop Pop Rap Latino Trap Rap Hiphop Pop Pop Pop Pop Rap Rap House Pop Pop Hiphop Rap Latino Trap Pop Latino Pop Trap Pop Rap Hiphop Hiphop Pop Latino Trap Latino Trap Trap Hiphop Rap Pop Rap Trap Pop Pop Trap Pop Trap Rap Trap Rap Latino Pop Rock Rock Pop Rap Hiphop Pop Hiphop Rap Trap Latino Trap Rock House Pop Pop Pop Hiphop Pop Rock Rock Pop Pop Pop Pop Pop Pop Rap House Pop'

# %%
wordcloud = WordCloud(width=800, height=400,max_words=30, background_color="white").generate(genres)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
#plt.savefig('/content/drive/MyDrive/Colab Notebooks/plot/Wordcloud.png', dpi=128)
plt.show()
